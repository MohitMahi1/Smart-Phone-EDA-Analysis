# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"smartphone_cleaned_v2.csv")

# %%
df
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 976   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 977      honor                      Honor X8 5G  14990    75.0    True
# 978       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 979   motorola             Motorola Moto G91 5G  19990    80.0    True
# 980    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster     processor_name processor_brand  num_cores  \
# ...

# %%
df.shape
# Out:
# (981, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981 entries, 0 to 980
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   brand_name            981 non-null    object
#  1   model                 981 non-null    object
#  2   price                 981 non-null    int64
#  3   rating                879 non-null    float64
#  4   has_5g                981 non-null    bool
#  5   has_nfc               981 non-null    bool
#  6   has_ir_blaster        981 non-null    bool
#  7   processor_name        961 non-null    object
#  8   processor_brand       961 non-null    object
#  9   num_cores             975 non-null    object
#  10  processor_speed       939 non-null    float64
#  11  ram_capacity          981 non-null    object
#  12  ram_capacity_num      981 non-null    float64
#  13  rom                   981 non-null    float64
#  14  battery_capacity      970 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# brand_name                0
# model                     0
# price                     0
# rating                  102
# has_5g                    0
# has_nfc                   0
# has_ir_blaster            0
# processor_name           20
# processor_brand          20
# num_cores                 6
# processor_speed          42
# ram_capacity              0
# ram_capacity_num          0
# rom                       0
# battery_capacity         11
# fast_charging             0
# screen_size               0
# resulation                0
# refresh_rate              0
# num_rear_cameras          0
# num_front_camera          0
# os                        0
# primary_camera_rear       0
# primary_camera_front      4
# extended_memory           0
# dtype: int64

# %% [markdown]
# ### Brand column

# %%
df['brand_name'].value_counts()
# Out:
# brand_name
# xiaomi       134
# samsung      132
# vivo         111
# realme        97
# oppo          88
# motorola      52
# apple         46
# oneplus       42
# poco          41
# tecno         33
# iqoo          32
# infinix       29
# huawei        16
# nokia         14
# google        14
# honor         13
# itel          10
# sony           9
# asus           7
# nubia          6
# nothing        5
# jio            4
# lava           4
# gionee         3
# letv           3
# redmi          3
# lg             3
# oukitel        3
# ikall          3
# micromax       3
# doogee         2
# lenovo         2
# zte            2
# lyf            2
# royole         2
# tesla          1
# cola           1
# leeco          1
# duoqin         1
# blu            1
# vertu          1
# leitz          1
# cat            1
# tcl            1
# sharp          1
# blackview      1
# Name: count, dtype: int64

# %%
# Find the top 10 brands 
df["brand_name"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='brand_name'>

# %% [markdown]
# Price column

# %%
# checking if null value are there
df["price"].isnull().sum()
# Out:
# np.int64(0)

# %%
# price column find all stats 
df["price"].describe()
# Out:
# count       981.000000
# mean      32492.440367
# std       39521.413990
# min        3499.000000
# 25%       12999.000000
# 50%       19990.000000
# 75%       35489.000000
# max      650000.000000
# Name: price, dtype: float64

# %%
# Plot a hist plot to know the graph of this price column
sns.histplot(df['price'],kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
# Checking the skewness of the price column
df["price"].skew()
# Out:
# np.float64(6.5920391948089145)

# %%
# Chekcing the phoens which is heigher then 200000
df[df["price"] > 200000]
# Out:
#     brand_name                                   model   price  rating  \
# 428      vertu                   Vertu Signature Touch  650000    62.0
# 479     huawei        Huawei Mate 50 RS Porsche Design  239999    81.0
# 888     xiaomi  Xiaomi Redmi K20 Pro Signature Edition  480000    88.0
# 952     huawei        Huawei Mate 30 RS Porsche Design  214990     NaN
#
#      has_5g  has_nfc  has_ir_blaster      processor_name processor_brand  \
# 428   False     True           False      snapdragon 801      snapdragon
# 479   False     True            True  snapdragon 8+ gen1      snapdragon
# 888   False     True           False     snapdragon  855      snapdragon
# 952    True     True            True          kirin  990           kirin
#
#      num_cores  ...  fast_charging screen_size   resulation  refresh_rate  \
# 428  octa core  ...             -1        4.70  1080 x 1920            60
# 479  octa core  ...             66        6.74  1212 x 2616           120
# ...

# %% [markdown]
# rating Column

# %%
df["rating"].describe()
# Out:
# count    879.000000
# mean      78.258248
# std        7.402854
# min       60.000000
# 25%       74.000000
# 50%       80.000000
# 75%       84.000000
# max       89.000000
# Name: rating, dtype: float64

# %%
# Ploting hist plot
sns.histplot(df["rating"], kde=True)
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
# checking skewness of the rating column
df["rating"].skew()
# Out:
# np.float64(-0.6989993034105536)

# %%
# Checking null values
df['rating'].isnull().sum()
# Out:
# np.int64(102)

# %%
# null values are filled with means value
df["rating"] = df["rating"].fillna(78.25)

# %% [markdown]
# has_5, has_nfc, has_ir_blaster columns

# %%
# df["has_5g"].value_counts().plot(kind="bar")
sns.countplot(data=df, x="has_5g")
# Out:
# <Axes: xlabel='has_5g', ylabel='count'>

# %%
sns.countplot(data=df,x="has_ir_blaster" )
# Out:
# <Axes: xlabel='has_ir_blaster', ylabel='count'>

# %%
sns.countplot(data=df, x="has_nfc")
# Out:
# <Axes: xlabel='has_nfc', ylabel='count'>

# %%
df["processor_brand"].value_counts()
# Out:
# processor_brand
# snapdragon    408
# helio         201
# dimensity     177
# exynos         49
# bionic         39
# unisoc         26
# tiger          24
# google          9
# kirin           7
# a13             5
# qualcomm        5
# spreadtrum      4
# sc9863a         2
# apple           1
# sanpdragon      1
# fusion          1
# mediatek        1
# samsung         1
# Name: count, dtype: int64

# %%
df['processor_brand'] = df['processor_brand'].str.replace('sanpdragon','snapdragon')
df['processor_brand'] = df['processor_brand'].str.replace('apple','bionic')
df['processor_brand'] = df['processor_brand'].str.replace('samsung','exynos')

# %%
temp_df = df[df['processor_brand'] == 'qualcomm']

# %%
df.loc[temp_df.index, 'processor_brand'] = 'snapdragon'

# %%
temp_df = df[df['processor_brand'] == 'a13']

# %%
df.loc[temp_df.index, 'processor_brand'] = 'bionic'

# %%
temp_df = df[df['processor_brand'] == 'mediatek']

# %%
df.loc[temp_df.index, 'processor_brand'] = 'dimensity'

# %%
df[df["processor_brand"].isnull()]
# Out:
#     brand_name                                 model  price  rating  has_5g  \
# 118      tesla                        Tesla Pi Phone  69999   83.00    True
# 143        jio                           Jio Phone 3   4499   78.25   False
# 188      ikall                         iKall Z19 Pro   8099   60.00   False
# 201    samsung                    Samsung Galaxy A13  14450   75.00   False
# 308    samsung  Samsung Galaxy A13 (4GB RAM + 128GB)  14999   75.00   False
# 314       itel                          itel S16 Pro   6990   78.25   False
# 491    samsung                    Samsung Galaxy A15  15990   63.00   False
# 524    samsung                    Samsung Galaxy F14  14990   67.00   False
# 576    samsung  Samsung Galaxy A13 (6GB RAM + 128GB)  16499   78.00   False
# 734      ikall                             iKall Z19   7999   61.00   False
# 754      tecno                   Tecno Spark Go 2022   6249   61.00   False
# ...

# %%
# checking numcores
df["num_cores"].value_counts()
# Out:
# num_cores
# octa core    899
# hexa core     39
# quad core     37
# Name: count, dtype: int64

# %%
# Checking what are the null value
df[df["num_cores"].isnull()]
# Out:
#     brand_name                    model   price  rating  has_5g  has_nfc  \
# 152      apple  Apple iPhone 15 Pro Max  142990    79.0    True     True
# 263      apple         Apple iPhone XR2   71999    60.0   False     True
# 281      apple     Apple iPhone 14 Mini   69990    70.0   False     True
# 426      nokia             Nokia X50 5G   34999    76.0    True    False
# 445      apple      Apple iPhone 15 Pro  130990    75.0    True     True
# 707      apple          Apple iPhone 15   82990    72.0   False     True
#
#      has_ir_blaster  processor_name processor_brand num_cores  ...  \
# 152           False     bionic  a16          bionic       NaN  ...
# 263           False      apple  a13          bionic       NaN  ...
# 281           False      bionic a16          bionic       NaN  ...
# 426           False  snapdragon 775      snapdragon       NaN  ...
# 445           False     bionic  a16          bionic       NaN  ...
# ...

# %%
# inject values 
df.loc[df["num_cores"].isna() & df["model"].str.contains("Apple", na=False),"num_cores"] = "hexa core"

# %%
# inject values 
df.loc[df["num_cores"].isna() & df["model"].str.contains("Nokia", na=False),"num_cores"] = "octa core"

# %%
# Processor_speed column
df[df['processor_speed'].isnull()]
# Out:
#     brand_name                            model   price  rating  has_5g  \
# 27       apple          Apple iPhone 14 Pro Max  129990   76.00    True
# 78     samsung            Samsung Galaxy A34 5G   24999   75.00    True
# 100      apple              Apple iPhone 14 Pro  119990   75.00    True
# 118      tesla                   Tesla Pi Phone   69999   83.00    True
# 122     google                  Google Pixel 6A   29999   71.00    True
# 129     google                  Google Pixel 7A   34990   69.00    True
# 152      apple          Apple iPhone 15 Pro Max  142990   79.00    True
# 207    samsung            Samsung Galaxy A54 5G   34999   76.00    True
# 210      apple  Apple iPhone 14 Pro Max (256GB)  139990   77.00    True
# 225       vivo                         Vivo Y02    8999   78.25   False
# 242    samsung            Samsung Galaxy A75 5G   44999   83.00    True
# 256    samsung         Samsung Galaxy S22 FE 5G   51999   79.00    True
# ...

# %%
df['processor_speed'].describe()
# Out:
# count    939.000000
# mean       2.426017
# std        0.465298
# min        1.200000
# 25%        2.050000
# 50%        2.300000
# 75%        2.840000
# max        3.220000
# Name: processor_speed, dtype: float64

# %%
df['processor_speed'].fillna(2.42, inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18220\3559174529.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['processor_speed'].fillna(2.42, inplace=True)

# %%
sns.kdeplot(data=df, x="processor_speed")
# Out:
# <Axes: xlabel='processor_speed', ylabel='Density'>

# %%
sns.boxplot(df['processor_speed'])
# Out:
# <Axes: ylabel='processor_speed'>

# %%
# Now checking the bettry capacity
df['battery_capacity'].describe()
# Out:
# count      970.000000
# mean      4814.276289
# std       1014.796456
# min       1450.000000
# 25%       4500.000000
# 50%       5000.000000
# 75%       5000.000000
# max      22000.000000
# Name: battery_capacity, dtype: float64

# %%
sns.kdeplot(data=df, x="battery_capacity")
# Out:
# <Axes: xlabel='battery_capacity', ylabel='Density'>

# %%
df[df["battery_capacity"].isnull()]
# Out:
#     brand_name                         model   price  rating  has_5g  has_nfc  \
# 111      apple               Apple iPhone 12   51999   74.00    True     True
# 149      apple          Apple iPhone 12 Mini   40999   74.00    True     True
# 306      apple       Apple iPhone 12 (128GB)   55999   75.00    True     True
# 362      apple  Apple iPhone 12 Mini (128GB)   45999   75.00    True     True
# 436      apple        Apple iPhone SE 3 2022   43900   78.25    True     True
# 445      apple           Apple iPhone 15 Pro  130990   75.00    True     True
# 614      apple   Apple iPhone 12 Pro (512GB)  139900   80.00    True     True
# 738      apple             Apple iPhone SE 4   49990   60.00    True     True
# 825      apple   Apple iPhone 12 Pro (256GB)  119900   80.00    True     True
# 881      apple  Apple iPhone 12 Mini (256GB)   55999   75.00    True     True
# 882      apple       Apple iPhone 12 (256GB)   67999   76.00    True     True
#
# ...

# %%
battery_map = {
    "Apple iPhone 12": 2815,
    "Apple iPhone 12 Mini": 2227,
    "Apple iPhone 12 (128GB)": 2815,
    "Apple iPhone 12 Mini (128GB)": 2227,
    "Apple iPhone SE 3 2022": 2018,
    "Apple iPhone 15 Pro": 3274,
    "Apple iPhone 12 Pro (512GB)": 3687,
    "Apple iPhone SE 4": 3279,
    "Apple iPhone 12 Pro (256GB)": 2815,
    "Apple iPhone 12 Mini (256GB)": 2227,
    "Apple iPhone 12 (256GB)": 3000
}

# %%
df["battery_capacity"] = df["battery_capacity"].fillna(
    df["model"].map(battery_map)
)

# %%
df[df["battery_capacity"].isna()]
# Out:
# Empty DataFrame
# Columns: [brand_name, model, price, rating, has_5g, has_nfc, has_ir_blaster, processor_name, processor_brand, num_cores, processor_speed, ram_capacity, ram_capacity_num, rom, battery_capacity, fast_charging, screen_size, resulation, refresh_rate, num_rear_cameras, num_front_camera, os, primary_camera_rear, primary_camera_front, extended_memory]
# Index: []
#
# [0 rows x 25 columns]

# %%
df['fast_charging'].describe()
# Out:
# count    981.000000
# mean      35.857288
# std       36.004989
# min       -1.000000
# 25%       10.000000
# 50%       30.000000
# 75%       65.000000
# max      240.000000
# Name: fast_charging, dtype: float64

# %%
def fast(row):

  if row['fast_charging'] == -1:
    return 0
  else:
    return 1

# %%
x = df.apply(fast,axis=1)
df.insert(16,'fast_charging_available',x)

# %%
df['fast_charging'] = df['fast_charging'].apply(lambda x:np.nan if x == 0 or x == -1 else x)

# %%
df.head()
# Out:
#   brand_name                      model  price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999    82.0    True    False
#
#    has_ir_blaster     processor_name processor_brand  num_cores  ...  \
# 0           False  snapdragon 8 gen2      snapdragon  octa core  ...
# 1           False     snapdragon 695      snapdragon  octa core  ...
# 2           False        exynos 1330          exynos  octa core  ...
# 3           False    snapdragon  695      snapdragon  octa core  ...
# 4           False     dimensity 1080       dimensity  octa core  ...
#
#    fast_charging_available screen_size   resulation  refresh_rate  \
# ...

# %%
# Now checking ram_capacity _num

# Chekcing null values
df["ram_capacity_num"].isnull().sum()
# Out:
# np.int64(0)

# %%
df['ram_capacity'].value_counts()
# Out:
# ram_capacity
# 8 GB      339
# 6 GB      234
# 4 GB      216
# 12 GB      85
# 3 GB       54
# 2 GB       32
# 16 GB       9
# 1 GB        7
# 18 GB       2
# 64 GB       2
# 512 GB      1
# Name: count, dtype: int64

# %%
df['rom'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['rom'].value_counts()
# Out:
# rom
# 128.0     523
# 64.0      193
# 256.0     157
# 32.0       67
# 512.0      23
# 16.0       12
# 1024.0      5
# 8.0         1
# Name: count, dtype: int64

# %%
# Now comming to screen size

# To see the describution of the screen_size
df['screen_size'].describe()
# Out:
# count    981.000000
# mean       6.532854
# std        0.369859
# min        2.700000
# 25%        6.500000
# 50%        6.580000
# 75%        6.670000
# max        8.030000
# Name: screen_size, dtype: float64

# %%
# Chekcing null value
df["screen_size"].isnull().sum()
# Out:
# np.int64(0)

# %%
# Now checking behaveour of the data
sns.kdeplot(data=df, x="screen_size")
# Out:
# <Axes: xlabel='screen_size', ylabel='Density'>

# %%
df['screen_size'].skew()
# Out:
# np.float64(-2.8882670182334)

# %%
sns.boxplot(df['screen_size'])
# Out:
# <Axes: ylabel='screen_size'>

# %%
# Now checking the resulation column

# Checking null value
df["resulation"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["resulation"].describe()
# Out:
# count             981
# unique             84
# top       1080 x 2400
# freq              342
# Name: resulation, dtype: object

# %%
# Now checking refresh_rate colmn

# chekcing null value
df["refresh_rate"].isnull().sum()
# Out:
# np.int64(0)

# %%
# refresh_rate valu count
df["refresh_rate"].value_counts()
# Out:
# refresh_rate
# 60     369
# 120    344
# 90     219
# 144     39
# 165      9
# 240      1
# Name: count, dtype: int64

# %%
# now comming to extended_memory
df['extended_memory'].value_counts()
# Out:
# extended_memory
# 0                       354
# 1 TB                    262
# 512 GB                  116
# 256 GB                  104
# Not Specified            88
# Memory Card (Hybrid)     31
# 128 GB                   10
# 2 TB                      8
# 32 GB                     4
# 64 GB                     3
# 1000 GB                   1
# Name: count, dtype: int64

# %%
df['extended_memory_available'] = df['extended_memory'].apply(lambda x:0 if x == '0' else 1)

# %%
def extended_extractor(row):

  if row['extended_memory_available'] == 0:
    return np.nan
  else:
    if row['extended_memory'] == '1 TB':
      return 1024
    elif row['extended_memory'] == '512 GB':
      return 512
    elif row['extended_memory'] == '256 GB':
      return 256
    elif row['extended_memory'] == 'Not Specified':
      return np.nan
    elif row['extended_memory'] == 'Memory Card (Hybrid)':
      return np.nan
    elif row['extended_memory'] == '128 GB':
      return 128
    elif row['extended_memory'] == '2 TB':
      return 2048
    elif row['extended_memory'] == '32 GB':
      return 32
    elif row['extended_memory'] == '64 GB':
      return 64
    elif row['extended_memory'] == '1000 GB':
      return 1000

# %%
def extended_extractor(row):

  if row['extended_memory_available'] == 0:
    return np.nan
  else:
    if row['extended_memory'] == 'Not Specified':
      return np.nan
    elif row['extended_memory'] == 'Memory Card (Hybrid)':
      return np.nan
    else:
      return row['extended_memory']

# %%
x = df.apply(extended_extractor,axis=1).str.replace('\u2009',' ').str.split(' ').str.get(0)

# %%
df['extended_memory_available']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 976    0
# 977    1
# 978    0
# 979    1
# 980    1
# Name: extended_memory_available, Length: 981, dtype: int64

# %%
df['extended_upto'] = x

# %%
df['extended_upto'].value_counts()
# Out:
# extended_upto
# 1       262
# 512     116
# 256     104
# 128      10
# 2         8
# 32        4
# 64        3
# 1000      1
# Name: count, dtype: int64

# %%
def transform(text):

  if text == '1':
    return '1024'
  elif text == '2':
    return '2048'
  elif text == '1000':
    return '1024'
  else:
    return text

# %%
df['extended_upto'] = df['extended_upto'].apply(transform)

# %%
df['extended_upto'].value_counts()
# Out:
# extended_upto
# 1024    263
# 512     116
# 256     104
# 128      10
# 2048      8
# 32        4
# 64        3
# Name: count, dtype: int64

# %%
df['os'].value_counts()
# Out:
# os
# android          910
# ios               46
# not specified     15
# other             10
# Name: count, dtype: int64

# %%
def os_transform(text):

  if 'Memory' in text:
    return np.nan
  elif 'android' in text:
    return text
  elif 'ios' in text:
    return text
  else:
    return 'other'

# %%
df['os'] = df['os'].apply(os_transform)

# %%
df.drop(columns=['processor_name','extended_memory', 'ram_capacity'],inplace=True)

# %%
df.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                         0
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand               20
# num_cores                      0
# processor_speed                0
# ram_capacity_num               0
# rom                            0
# battery_capacity               0
# fast_charging                212
# fast_charging_available        0
# screen_size                    0
# resulation                     0
# refresh_rate                   0
# num_rear_cameras               0
# num_front_camera               0
# os                             0
# primary_camera_rear            0
# primary_camera_front           4
# extended_memory_available      0
# extended_upto                473
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981 entries, 0 to 980
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 981 non-null    object
#  1   model                      981 non-null    object
#  2   price                      981 non-null    int64
#  3   rating                     981 non-null    float64
#  4   has_5g                     981 non-null    bool
#  5   has_nfc                    981 non-null    bool
#  6   has_ir_blaster             981 non-null    bool
#  7   processor_brand            961 non-null    object
#  8   num_cores                  981 non-null    object
#  9   processor_speed            981 non-null    float64
#  10  ram_capacity_num           981 non-null    float64
#  11  rom                        981 non-null    float64
#  12  battery_capacity           981 non-null    float64
# ...

# %%
df['primary_camera_front'].value_counts()
# Out:
# primary_camera_front
# 16      307
# 8       178
# 32      156
# 5       119
# 12       50
# 13       41
# 20       37
# 10       24
# 50       12
# 60       10
# 44        8
# 40        6
# 2         5
# 7         5
# 10.8      3
# 25        3
# 24        3
# 48        2
# 11.1      2
# 2.1       1
# 0.3       1
# Main      1
# 10.7      1
# 10.1      1
# 12.6      1
# Name: count, dtype: int64

# %%
df['primary_camera_front'] = df['primary_camera_front'].apply(lambda x: np.nan if x == 'Main' else x).astype(float)

# %%
df['num_cores'].value_counts()
# Out:
# num_cores
# octa core    900
# hexa core     44
# quad core     37
# Name: count, dtype: int64

# %%
df['num_cores'] = df['num_cores'].str.replace('octa core','8')
df['num_cores'] = df['num_cores'].str.replace('hexa core','6')
df['num_cores'] = df['num_cores'].str.replace('quad core','4')

# %%
df['num_cores'].value_counts()
# Out:
# num_cores
# 8    900
# 6     44
# 4     37
# Name: count, dtype: int64

# %%
df
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 976   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 977      honor                      Honor X8 5G  14990    75.0    True
# 978       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 979   motorola             Motorola Moto G91 5G  19990    80.0    True
# 980    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand num_cores  processor_speed  ...  \
# ...
